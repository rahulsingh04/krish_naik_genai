# %% [markdown]
# ### Data Ingestion Document Loader
#
# https://python.langchain.com/v0.2/docs/integrations/document_loaders/

# %%
### Text Loader 
from langchain_community.document_loaders import TextLoader
loader = TextLoader(r'C:\vs_code\Genai\bctech2011.txt')
loader

# %%
text_document = loader.load()
text_document
# Out:
# [Document(metadata={'source': 'C:\\vs_code\\Genai\\bctech2011.txt'}, page_content='Title: ML and AI-based insurance premium model to predict premium to be charged by the insurance company - Blackcoffer Insights\n\nHome\nOur Success Stories\nML and AI-based insurance premium model to predict premium to be charged...\nOur Success Stories\nBanking, Financials, Securities, and Insurance\nML and AI-based insurance premium model to predict premium to be charged by the insurance company\nBy\nAjay Bidyarthy\n-\nJanuary 7, 2024\n3648\nClient Background\nClient:\nA leading insurance firm worldwide\nIndustry Type:\nBFSI\nProducts & Services:\nInsurance\nOrganization Size:\n10000+\nThe Problem\nThe insurance industry, particularly in the context of providing coverage to Public Company Directors against Insider Trading public lawsuits, faces a significant challenge in accurately determining insurance premiums. Traditional methods of premium calculation may lack precision, and there is a growing n
# ...

# %%
### Reading A PDF FILE 
from langchain_community.document_loaders import PyPDFLoader
loader = PyPDFLoader("test.pdf")
docs = loader.load()

## type(docs)  ## It Is A List
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 3
#       1 ### Reading A PDF FILE
#       2 from langchain_community.document_loaders import PyPDFLoader
# ----> 3 loader = PyPDFLoader("test.pdf")
#       4 docs = loader.load()
#       6 ## type(docs)  ## It Is A List
#
# File c:\vs_code\Genai\genai_env\Lib\site-packages\langchain_community\document_loaders\pdf.py:186, in PyPDFLoader.__init__(self, file_path, password, headers, extract_images, extraction_mode, extraction_kwargs)
#     182 except ImportError:
#     183     raise ImportError(
#     184         "pypdf package not found, please install it with " "`pip install pypdf`"
#     185     )
# --> 186 super().__init__(file_path, headers=headers)
#     187 self.parser = PyPDFParser(
#     188     password=password,
#     189     extract_images=extract_images,
#     190     extraction_mode=extraction_mode,
# ...

# %%
### Web Base Loader 

from langchain_community.document_loaders import WebBaseLoader
loader = WebBaseLoader(web_path=('https://www.scribbledata.io/blog/large-language-models-history-evolutions-and-future/' , ),
                       bs_kwargs = dict(parse_only = bs4.SoupStrainer(
                           class_ = ("post-title", "post-content", "post-header")
                       )))
# Out:
# USER_AGENT environment variable not set, consider setting it to identify your requests.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 5
#       1 ### Web Base Loader
#       3 from langchain_community.document_loaders import WebBaseLoader
#       4 loader = WebBaseLoader(web_path=('https://www.scribbledata.io/blog/large-language-models-history-evolutions-and-future/' , ),
# ----> 5                        bs_kwargs = dict(parse_only = bs4.SoupStrainer(
#       6                            class_ = ("post-title", "post-content", "post-header")
#       7                        )))
#
# NameError: name 'bs4' is not defined

# %%
## WikiPedia Loader 
from langchain_community.document_loaders import WikipediaLoader
docs = WikipediaLoader(query = 'michael_jackson',  load_max_docs =2).load()
len(docs)
# Out:
# 2

# %%
docs
# Out:
# [Document(metadata={'title': 'Michael Jackson', 'summary': 'Michael Joseph Jackson (August 29, 1958 – June 25, 2009) was an American singer, songwriter, dancer, and philanthropist. Dubbed the "King of Pop", he is regarded as one of the most significant cultural figures of the 20th century. Over a four-decade career, his contributions to music, dance, and fashion, along with his publicized personal life, made him a global figure in popular culture. Jackson influenced artists across many music genres. Through stage and video performances, he popularized street dance moves such as the moonwalk, which he named, and the robot.\nHe was the eighth child of the Jackson family, and made his public debut in 1964 with his older brothers Jackie, Tito, Jermaine, and Marlon as a member of the Jackson 5 (later known as the Jacksons). The Jackson 5 signed with Motown in 1968 and achieved worldwide success with Michael as lead singer. Jackson began his solo career in 1971 while at Motown and recorded
# ...
