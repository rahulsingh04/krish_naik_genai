# %% [markdown]
# #### Hugging Face x LangChain : A New Partner Package In Langchain
#
# langchain _ HuggingFace, a partner package in Langchain jointly maintained by Hugging Face And Langchain .
# This New Python Package is designed to bring the power of the latest development of Hugging Face into the Langchain
# And Keep it up to date .

# %%
import os 
from dotenv import load_dotenv
load_dotenv()
HuggingFaceApi = os.getenv('HF_TOKEN')

# %%
from langchain_huggingface import HuggingFaceEndpoint

# %%
repo_id = 'mistralai/Mistral-7B-Instruct-v0.3'
llm = HuggingFaceEndpoint(
    repo_id=repo_id,
    max_length = 150,
    temperature = 0.7,
    token = HuggingFaceApi
)
# Out:
# WARNING! max_length is not default parameter.
#                     max_length was transferred to model_kwargs.
#                     Please make sure that max_length is what you intended.
# WARNING! token is not default parameter.
#                     token was transferred to model_kwargs.
#                     Please make sure that token is what you intended.

# %%
llm
# Out:
# HuggingFaceEndpoint(repo_id='mistralai/Mistral-7B-Instruct-v0.3', temperature=0.7, model_kwargs={'max_length': 150, 'token': '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'}, model='mistralai/Mistral-7B-Instruct-v0.3', client=<InferenceClient(model='mistralai/Mistral-7B-Instruct-v0.3', timeout=120)>, async_client=<InferenceClient(model='mistralai/Mistral-7B-Instruct-v0.3', timeout=120)>)

# %%
llm.invoke('what is genai')
# Out:
# "?\n\nGenAI is a cutting-edge artificial intelligence model developed by Mistral AI, a leading AI company based in Paris, France. GenAI is designed to understand and generate human-like text, making it a powerful tool for a wide range of applications, including language translation, text summarization, and content creation. It's important to note that GenAI is not a specific product or service available to the general public yet, but it's a testament to the advancements in AI technology being made by Mistral AI."

# %%
# llm.invoke("what is machine learning ?")

# %%
from langchain import PromptTemplate, LLMChain

template = """ 
Question:{question}
Answer  :Let's Think Step By Step. 
        """
prompt = PromptTemplate(template = template, input_variables = ['question'])
prompt
# Out:
# PromptTemplate(input_variables=['question'], template=" \nQuestion:{question}\nAnswer  :Let's Think Step By Step. \n        ")

# %%
llm_chain = prompt|llm
llm.invoke("Who Won The World Cup 2011 ?")
# Out:
# "\n\nIndia\nIndia won the 2011 Cricket World Cup. The team defeated Sri Lanka in the final by six wickets. India was the host country and had qualified for the tournament automatically. The final was played on April 2, 2011 at the Wankhede Stadium in Mumbai. India had previously won the World Cup in 1983.\n\nThis was India's second World Cup victory and it was the first time that a team had won the World Cup on home soil. India's captain, Mahendra Singh Dhoni, was named the Man of the Match for his unbeaten 91 runs in the final.\n\nThe 2011 World Cup was a significant tournament for India, as it came at a time when the team was experiencing a period of great success. India had recently won the 2007 T20 World Cup and the 2010 ICC Champions Trophy, and the 2011 World Cup was seen as an opportunity to complete a hat-trick of ICC titles. The team's success in the World Cup was also a testament to the development of cricket in India, as it demonstrated the country's ability to produce wor
# ...
